# %%
import pandas as pd
import ast
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# %%
def geocode_location(location_str):
    geolocator = Nominatim(user_agent="attraction_finder")
    location = geolocator.geocode(location_str)
    return (location.latitude, location.longitude) if location else None

# %%
def find_nearby_restaurants(user_location_str, df, radius_km=10):
    user_coords = geocode_location(user_location_str)
    if not user_coords:
        return pd.DataFrame()
    
    def compute_distance(row):
        if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
            return geodesic(user_coords, (row['latitude'], row['longitude'])).km
        return float('inf')

    df['distance_km'] = df.apply(compute_distance, axis=1)
    nearby_df = df[df['distance_km'] <= radius_km].sort_values(by='distance_km')
    return nearby_df[['Name', 'Address', 'Duration', 'Rating', 'Ranking', 'distance_km']]

# %%
def generate_fallbacks(address):
    """Trả về danh sách các địa chỉ fallback theo mức độ đơn giản dần"""
    parts = [p.strip() for p in address.split(',') if p.strip()]
    fallbacks = []

    if len(parts) >= 4:
        fallbacks.append(', '.join(parts[-4:]))
    if len(parts) >= 3:
        fallbacks.append(', '.join(parts[-3:]))
    if len(parts) >= 2:
        fallbacks.append(', '.join(parts[-2:]))
    if len(parts) >= 1:
        fallbacks.append(parts[-1])

    return fallbacks


# Hàm geocode có fallback tự động cho SEA
def add_lat_lon_with_fallback(df, sample_size=None):
    geolocator = Nominatim(user_agent="attraction_finder_sea", timeout=10)
    latitudes = []
    longitudes = []

    df_sample = df.head(sample_size).copy()

    for i, row in df_sample.iterrows():
        raw_address = row['Address']
        try:
            print(f"[{i+1}/{len(df_sample)}] Geocoding: {raw_address}")
            location = geolocator.geocode(raw_address)

            if location:
                latitudes.append(location.latitude)
                longitudes.append(location.longitude)
                print(f"   ✅ Found: ({location.latitude}, {location.longitude})")
            else:
                # fallback nhiều cấp độ
                fallbacks = generate_fallbacks(raw_address)
                found = False

                for fb in fallbacks:
                    print(f"   ↪️ Trying fallback: {fb}")
                    fb_loc = geolocator.geocode(fb)
                    if fb_loc:
                        latitudes.append(fb_loc.latitude)
                        longitudes.append(fb_loc.longitude)
                        print(f"   ✅ Fallback Success: ({fb_loc.latitude}, {fb_loc.longitude})")
                        found = True
                        break

                if not found:
                    latitudes.append(None)
                    longitudes.append(None)
                    print(f"   ❌ All Fallbacks Failed for: {raw_address}")
        except Exception as e:
            latitudes.append(None)
            longitudes.append(None)
            print(f"   ❌ Error for '{raw_address}': {e}")

    df_sample['latitude'] = latitudes
    df_sample['longitude'] = longitudes
    return df_sample

# %%
import os

def process_in_chunks_resumable(df, chunk_size=5000, start_index=0, output_folder="geo_batches_attractions"):
    os.makedirs(output_folder, exist_ok=True)

    total = len(df)
    num_chunks = (total - start_index) // chunk_size + 1

    for i in range(num_chunks):
        chunk_start = start_index + i * chunk_size
        chunk_end = min(chunk_start + chunk_size, total)
        chunk_filename = f"{output_folder}/geo_results_batch_{i+1}.csv"

        # Bỏ qua nếu file đã tồn tại
        if os.path.exists(chunk_filename):
            print(f"✅ Đã có: {chunk_filename}, bỏ qua...")
            continue

        df_chunk = df.iloc[chunk_start:chunk_end]
        print(f"\n📦 Đang xử lý dòng {chunk_start} đến {chunk_end}")

        df_processed = add_lat_lon_with_fallback(df_chunk, sample_size=None)
        df_processed.to_csv(chunk_filename, index=False)
        print(f"💾 Đã lưu: {chunk_filename}")

# %%
df_all = pd.read_csv("Attraction_Data\Attraction_Tripadvisor_Data_SEA_cleanedforweb.csv")

# %%
import re

def clean_thai_address(address):
    """
    Xử lý 'Moo' trong địa chỉ Thái Lan để cải thiện khả năng geocode.
    """
    if pd.isnull(address):
        return address
    # Xóa cụm 'Moo xx' (có thể viết 'Moo.10', 'Moo 10',...)
    address = re.sub(r'\bMoo\.?\s*\d+\b', '', address, flags=re.IGNORECASE)
    # Xóa dấu ',' hoặc khoảng trắng dư thừa
    address = re.sub(r'\s*,\s*', ', ', address)
    address = re.sub(r'\s{2,}', ' ', address)
    return address.strip(", ")

df_all['Address'] = df_all['Address'].apply(clean_thai_address)

# %%
# Chạy theo batch 5.000 dòng → bỏ qua những batch đã xử lý
process_in_chunks_resumable(df_all, chunk_size=5000)
# Out:
# ✅ Đã có: geo_batches_attractions/geo_results_batch_1.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_2.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_3.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_4.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_5.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_6.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_7.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_8.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_9.csv, bỏ qua...
# ✅ Đã có: geo_batches_attractions/geo_results_batch_10.csv, bỏ qua...
#
# 📦 Đang xử lý dòng 50000 đến 55000
# [50001/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50002/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50003/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50004/5000] Geocoding: Banjar Pagutan Kaja, Batubulan, Sukawati, Indonesia
#    ↪️ Trying fallback: Banjar Pagutan Kaja, Batubulan, Sukawati, Indonesia
#    ↪️ Trying fallback: Batubulan, Sukawati, Indonesia
#    ✅ Fallback Success: (-8.6151413, 115.2588933)
# [50005/5000] Geocoding: Jl. Drupadi 1 no. 7, Banjar Basangkasa, Seminyak, Indonesia
#    ↪️ Trying fallback: Jl. Drupadi 1 no. 7, Banjar Basangkasa, Seminyak, Indonesia
#    ↪️ Trying fallback: Banjar Basangkasa, Seminyak, Indonesia
#    ✅ Fallback Success: (-8.6857862, 115.1670544)
# [50006/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50007/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50008/5000] Geocoding: Jl. Wirasaba no. 5 eqUILIBRIA Hotel, Seminyak, Indonesia
#    ↪️ Trying fallback: Jl. Wirasaba no. 5 eqUILIBRIA Hotel, Seminyak, Indonesia
#    ↪️ Trying fallback: Seminyak, Indonesia
#    ✅ Fallback Success: (-8.6908357, 115.1641975)
# [50009/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50010/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50011/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50012/5000] Geocoding: Tegalgundul square, Canggu, Indonesia
#    ↪️ Trying fallback: Tegalgundul square, Canggu, Indonesia
#    ↪️ Trying fallback: Canggu, Indonesia
#    ✅ Fallback Success: (-8.6506193, 115.1365007)
# [50013/5000] Geocoding: Jl. Tirta Akasa no. 28, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Jl. Tirta Akasa no. 28, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Sanur, Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6831728, 115.2564626)
# [50014/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50015/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50016/5000] Geocoding: Jl. Pura Kramat, Seseh, Mengwi, Indonesia
#    ↪️ Trying fallback: Jl. Pura Kramat, Seseh, Mengwi, Indonesia
#    ↪️ Trying fallback: Seseh, Mengwi, Indonesia
#    ↪️ Trying fallback: Mengwi, Indonesia
#    ✅ Fallback Success: (-8.5448561, 115.1691369)
# [50017/5000] Geocoding: Jl. Raya Ubud at the bridge beside Murni's Warung, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Raya Ubud at the bridge beside Murni's Warung, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50018/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50019/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50020/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50021/5000] Geocoding: Desa Pancasari - Singaraja, Singaraja, Indonesia
#    ↪️ Trying fallback: Desa Pancasari - Singaraja, Singaraja, Indonesia
#    ↪️ Trying fallback: Singaraja, Indonesia
#    ✅ Fallback Success: (-8.1133599, 115.0839326)
# [50022/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50023/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50024/5000] Geocoding: Jalan Raya Pejang Kawan, Banjar Laplapan Ubud, Petulu, Ubud, Indonesia
#    ↪️ Trying fallback: Banjar Laplapan Ubud, Petulu, Ubud, Indonesia
#    ↪️ Trying fallback: Petulu, Ubud, Indonesia
#    ✅ Fallback Success: (-8.4825898, 115.2761104)
# [50025/5000] Geocoding: Jalan Raya Andong No. 15, Ubud, Indonesia
#    ✅ Found: (-8.5065388, 115.2716699)
# [50026/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50027/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50028/5000] Geocoding: Jl. Camplung Tanduk no. 07, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Jl. Camplung Tanduk no. 07, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Sanur, Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6831728, 115.2564626)
# [50029/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50030/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50031/5000] Geocoding: Jalan Dewi Saraswati No. 88, Kerobokan, Indonesia
#    ✅ Found: (-8.6807048, 115.1714113)
# [50032/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50033/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50034/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50035/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50036/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50037/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50038/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50039/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50040/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50041/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50042/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50043/5000] Geocoding: Jl. Raya Pengosekan, Ubud, Indonesia
#    ✅ Found: (-8.5211544, 115.262996)
# [50044/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50045/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50046/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50047/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50048/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50049/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50050/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50051/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50052/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50053/5000] Geocoding: Jalan Letda Tantular No 47A, Danginpuri Kelod, Denpasar, Indonesia
#    ↪️ Trying fallback: Jalan Letda Tantular No 47A, Danginpuri Kelod, Denpasar, Indonesia
#    ↪️ Trying fallback: Danginpuri Kelod, Denpasar, Indonesia
#    ↪️ Trying fallback: Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6524973, 115.2191175)
# [50054/5000] Geocoding: Jl. Nyuh Bulan Nyuh Kuning, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Nyuh Bulan Nyuh Kuning, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50055/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50056/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50057/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50058/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50059/5000] Geocoding: Jl. Pantai Batu Bolong No. 72, Canggu, Indonesia
#    ✅ Found: (-8.6447123, 115.1414973)
# [50060/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50061/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50062/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50063/5000] Geocoding: Jalan Nakula No. 8 Seminyak, Seminyak, Indonesia
#    ✅ Found: (-8.6971925, 115.1707167)
# [50064/5000] Geocoding: Jl. Raya Sanggingan 88x Indomaret Lt. 2, Cahaya Intan, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Raya Sanggingan 88x Indomaret Lt. 2, Cahaya Intan, Ubud, Indonesia
#    ↪️ Trying fallback: Cahaya Intan, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50065/5000] Geocoding: The Prama Hotel, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: The Prama Hotel, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Sanur, Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6831728, 115.2564626)
# [50066/5000] Geocoding: Jalan Nakula 3rd Floor Kawan Mini Market, Kuta, Indonesia
#    ↪️ Trying fallback: Jalan Nakula 3rd Floor Kawan Mini Market, Kuta, Indonesia
#    ↪️ Trying fallback: Kuta, Indonesia
#    ✅ Fallback Success: (-8.7278354, 115.1730049)
# [50067/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50068/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50069/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50070/5000] Geocoding: Uluwatu Surf Villas Jl. Pantai Suluban, Uluwatu, Pecatu, Indonesia
#    ↪️ Trying fallback: Uluwatu Surf Villas Jl. Pantai Suluban, Uluwatu, Pecatu, Indonesia
#    ↪️ Trying fallback: Uluwatu, Pecatu, Indonesia
#    ✅ Fallback Success: (-8.8272855, 115.0889841)
# [50071/5000] Geocoding: Jl. Laksamana no. 1 Oberoi, Seminyak, Indonesia
#    ↪️ Trying fallback: Jl. Laksamana no. 1 Oberoi, Seminyak, Indonesia
#    ↪️ Trying fallback: Seminyak, Indonesia
#    ✅ Fallback Success: (-8.6908357, 115.1641975)
# [50072/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50073/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50074/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50075/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50076/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50077/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50078/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50079/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50080/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50081/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50082/5000] Geocoding: Km 4 Jl. Melayang, Ubud, Indonesia
#    ↪️ Trying fallback: Km 4 Jl. Melayang, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50083/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50084/5000] Geocoding: Jl. Belimbing Sari lll No. 3, Pecatu, Indonesia
#    ↪️ Trying fallback: Jl. Belimbing Sari lll No. 3, Pecatu, Indonesia
#    ↪️ Trying fallback: Pecatu, Indonesia
#    ✅ Fallback Success: (-8.8266671, 115.1149608)
# [50085/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50086/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50087/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50088/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50089/5000] Geocoding: Jl. Petitenget no. 106 Seminyak, Kuta Utara, Kabupaten Badung, Indonesia
#    ↪️ Trying fallback: Jl. Petitenget no. 106 Seminyak, Kuta Utara, Kabupaten Badung, Indonesia
#    ↪️ Trying fallback: Kuta Utara, Kabupaten Badung, Indonesia
#    ✅ Fallback Success: (-8.6901665, 115.1722749)
# [50090/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50091/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50092/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50093/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50094/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50095/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50096/5000] Geocoding: Jalan Raya Keliki No.123, Tegalalang, Ubud, Bali, Indonesia Abisena Ubud, Tegalalang, Indonesia
#    ↪️ Trying fallback: Bali, Indonesia Abisena Ubud, Tegalalang, Indonesia
#    ↪️ Trying fallback: Indonesia Abisena Ubud, Tegalalang, Indonesia
#    ↪️ Trying fallback: Tegalalang, Indonesia
#    ↪️ Trying fallback: Indonesia
#    ✅ Fallback Success: (-2.4833826, 117.8902853)
# [50097/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50098/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50099/5000] Geocoding: Jl. Jembawan 1 No.27 Padang Tegal, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Jembawan 1 No.27 Padang Tegal, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50100/5000] Geocoding: Jl. Suweta no. 45 (just 500 meters from Ubud palace), Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Suweta no. 45 (just 500 meters from Ubud palace), Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50101/5000] Geocoding: Jl. Pantai Berawa No.99 Tamora Gallery, Tibubeneng, Indonesia
#    ↪️ Trying fallback: Jl. Pantai Berawa No.99 Tamora Gallery, Tibubeneng, Indonesia
#    ↪️ Trying fallback: Tibubeneng, Indonesia
#    ✅ Fallback Success: (-8.6451772, 115.1519964)
# [50102/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50103/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50104/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50105/5000] Geocoding: Jl. Kartika Plaza No.90 X, Kuta, Indonesia
#    ↪️ Trying fallback: Jl. Kartika Plaza No.90 X, Kuta, Indonesia
#    ↪️ Trying fallback: Kuta, Indonesia
#    ✅ Fallback Success: (-8.7278354, 115.1730049)
# [50106/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50107/5000] Geocoding: Gg. Lumut, Seminyak, Indonesia
#    ✅ Found: (-8.6851006, 115.1610355)
# [50108/5000] Geocoding: Jl. Monkey Forest in the opposite of Pertiwi Resort, next to Sri Bungalows, in the small alley, Ubud, Indonesia
#    ↪️ Trying fallback: next to Sri Bungalows, in the small alley, Ubud, Indonesia
#    ↪️ Trying fallback: in the small alley, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50109/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50110/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50111/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50112/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50113/5000] Geocoding: Jl. Tirta Tawar No.66, Kutuh Kaja Kecamatan Ubud, Kabupaten Gianyar, Bali, Ubud, Indonesia
#    ↪️ Trying fallback: Kabupaten Gianyar, Bali, Ubud, Indonesia
#    ✅ Fallback Success: (-8.5088387, 115.2703173)
# [50114/5000] Geocoding: Jalan Raya Payangan Gianyar Bali, Melinggih Kelod, Payangan, Indonesia
#    ↪️ Trying fallback: Jalan Raya Payangan Gianyar Bali, Melinggih Kelod, Payangan, Indonesia
#    ↪️ Trying fallback: Melinggih Kelod, Payangan, Indonesia
#    ↪️ Trying fallback: Payangan, Indonesia
#    ✅ Fallback Success: (-8.4252668, 115.2455213)
# [50115/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50116/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50117/5000] Geocoding: No.8 Jl. Banteng II Bengkel Kawan, Tampih, Kediri, Indonesia
#    ↪️ Trying fallback: No.8 Jl. Banteng II Bengkel Kawan, Tampih, Kediri, Indonesia
#    ↪️ Trying fallback: Tampih, Kediri, Indonesia
#    ↪️ Trying fallback: Kediri, Indonesia
#    ✅ Fallback Success: (-7.8111057, 112.0046051)
# [50118/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50119/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50120/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50121/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50122/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50123/5000] Geocoding: Jl. Nusa Dua Art Market Main Gate, Enclive Bali, Nusa Dua, Benoa, Indonesia
#    ↪️ Trying fallback: Enclive Bali, Nusa Dua, Benoa, Indonesia
#    ↪️ Trying fallback: Nusa Dua, Benoa, Indonesia
#    ✅ Fallback Success: (-8.8016777, 115.2239305)
# [50124/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50125/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50126/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50127/5000] Geocoding: Jln. Danau Tamblingan 104, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Jln. Danau Tamblingan 104, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Sanur, Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6831728, 115.2564626)
# [50128/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50129/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50130/5000] Geocoding: Jl. Nelayan No.1 Blok A, Banjar Badung, Canggu, Indonesia
#    ↪️ Trying fallback: Jl. Nelayan No.1 Blok A, Banjar Badung, Canggu, Indonesia
#    ↪️ Trying fallback: Banjar Badung, Canggu, Indonesia
#    ↪️ Trying fallback: Canggu, Indonesia
#    ✅ Fallback Success: (-8.6506193, 115.1365007)
# [50131/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50132/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50133/5000] Geocoding: Jl. Raya Kedewatan Mason Adventure Centre, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Raya Kedewatan Mason Adventure Centre, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50134/5000] Geocoding: Jl. Danau Tamblingan no. 68-72, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Jl. Danau Tamblingan no. 68-72, Sanur, Denpasar, Indonesia
#    ↪️ Trying fallback: Sanur, Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6831728, 115.2564626)
# [50135/5000] Geocoding: Jl. Arjuna No. 28, Seminyak, Indonesia
#    ✅ Found: (-8.6970619, 115.1673681)
# [50136/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50137/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50138/5000] Geocoding: Jl. SMKI no. 25, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. SMKI no. 25, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50139/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50140/5000] Geocoding: Jl Raya Kedampang, Kerobokan Kelod, Indonesia
#    ✅ Found: (-8.6644802, 115.1722133)
# [50141/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50142/5000] Geocoding: Jl. Legian No.358, Kuta, Indonesia
#    ↪️ Trying fallback: Jl. Legian No.358, Kuta, Indonesia
#    ↪️ Trying fallback: Kuta, Indonesia
#    ✅ Fallback Success: (-8.7278354, 115.1730049)
# [50143/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50144/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50145/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50146/5000] Geocoding: Jl. Hanoman Plataran Ubud Hotel & Spa, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Hanoman Plataran Ubud Hotel & Spa, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50147/5000] Geocoding: Jln. Pulau Sulawesi 19, Denpasar, Indonesia
#    ↪️ Trying fallback: Jln. Pulau Sulawesi 19, Denpasar, Indonesia
#    ↪️ Trying fallback: Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6524973, 115.2191175)
# [50148/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50149/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50150/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50151/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50152/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50153/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50154/5000] Geocoding: Jl. Raya Batubulan Gg. Candrametu no. 1, Denpasar, Indonesia
#    ↪️ Trying fallback: Jl. Raya Batubulan Gg. Candrametu no. 1, Denpasar, Indonesia
#    ↪️ Trying fallback: Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6524973, 115.2191175)
# [50155/5000] Geocoding: Jln Raya Batuan, Sukawati, Indonesia
#    ↪️ Trying fallback: Jln Raya Batuan, Sukawati, Indonesia
#    ↪️ Trying fallback: Sukawati, Indonesia
#    ✅ Fallback Success: (-8.5961547, 115.2820391)
# [50156/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50157/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50158/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50159/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50160/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50161/5000] Geocoding: Gg. Cemp Alamanda Resort Lovina, Kayu Putih, Sukasada, Indonesia
#    ↪️ Trying fallback: Gg. Cemp Alamanda Resort Lovina, Kayu Putih, Sukasada, Indonesia
#    ↪️ Trying fallback: Kayu Putih, Sukasada, Indonesia
#    ↪️ Trying fallback: Sukasada, Indonesia
#    ✅ Fallback Success: (-8.1688679, 115.1408302)
# [50162/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50163/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50164/5000] Geocoding: Jl. Umalas 2 no. 92, Kerobokan, Indonesia
#    ↪️ Trying fallback: Jl. Umalas 2 no. 92, Kerobokan, Indonesia
#    ↪️ Trying fallback: Kerobokan, Indonesia
#    ✅ Fallback Success: (-8.650608, 115.1631544)
# [50165/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50166/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50167/5000] Geocoding: Bali Yoga Teacher Training center, Ubud, Indonesia
#    ↪️ Trying fallback: Bali Yoga Teacher Training center, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50168/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50169/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50170/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50171/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50172/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50173/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50174/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50175/5000] Geocoding: Jl. Raya Singapadu Gang Beji The Sanctoo Villa, Sukawati, Indonesia
#    ↪️ Trying fallback: Jl. Raya Singapadu Gang Beji The Sanctoo Villa, Sukawati, Indonesia
#    ↪️ Trying fallback: Sukawati, Indonesia
#    ✅ Fallback Success: (-8.5961547, 115.2820391)
# [50176/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50177/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50178/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50179/5000] Geocoding: Jalan Raya Bona, Gianyar, Ubud, Indonesia
#    ↪️ Trying fallback: Jalan Raya Bona, Gianyar, Ubud, Indonesia
#    ↪️ Trying fallback: Gianyar, Ubud, Indonesia
#    ✅ Fallback Success: (-8.5119399, 115.2378113)
# [50180/5000] Geocoding: Central Ubud Street Mumbul Inn, Ubud, Indonesia
#    ↪️ Trying fallback: Central Ubud Street Mumbul Inn, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50181/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50182/5000] Geocoding: Jl. By Pass Ngurah Rai, Kuta, Indonesia
#    ✅ Found: (-8.7413095, 115.18115)
# [50183/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50184/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50185/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50186/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50187/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50188/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50189/5000] Geocoding: Jl. Pratama No.34A Opposite of Sol House Benoa, Benoa, Indonesia
#    ↪️ Trying fallback: Jl. Pratama No.34A Opposite of Sol House Benoa, Benoa, Indonesia
#    ↪️ Trying fallback: Benoa, Indonesia
#    ✅ Fallback Success: (-8.8007914, 115.2105452)
# [50190/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50191/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50192/5000] Geocoding: Jl. Sukma Kesuma No.19-27, Peliatan, Kecamatan Ubud, Kabupaten Gianyar, Bali 80571, Gianyar, Indonesia
#    ↪️ Trying fallback: Kabupaten Gianyar, Bali 80571, Gianyar, Indonesia
#    ✅ Fallback Success: (-8.5088387, 115.2703173)
# [50193/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50194/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50195/5000] Geocoding: Batungsel, Pupuan, Indonesia
#    ↪️ Trying fallback: Batungsel, Pupuan, Indonesia
#    ↪️ Trying fallback: Pupuan, Indonesia
#    ✅ Fallback Success: (-8.3173707, 115.0076504)
# [50196/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50197/5000] Geocoding: Jl. Pura Mertasari no. 27, Sunset Road, Kuta, Indonesia
#    ↪️ Trying fallback: Jl. Pura Mertasari no. 27, Sunset Road, Kuta, Indonesia
#    ↪️ Trying fallback: Sunset Road, Kuta, Indonesia
#    ✅ Fallback Success: (-8.7078297, 115.1836034)
# [50198/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50199/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50200/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50201/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50202/5000] Geocoding: Jl. Pura Mastima, Jasri Kelod, Karangasem, Indonesia
#    ↪️ Trying fallback: Jl. Pura Mastima, Jasri Kelod, Karangasem, Indonesia
#    ↪️ Trying fallback: Jasri Kelod, Karangasem, Indonesia
#    ↪️ Trying fallback: Karangasem, Indonesia
#    ✅ Fallback Success: (-8.3355616, 115.617073)
# [50203/5000] Geocoding: Jl. Kiskinda, Mayong, Kec. Seririt, kabupaten Buleleng, Bali 81153, Seririt, Indonesia
#    ↪️ Trying fallback: kabupaten Buleleng, Bali 81153, Seririt, Indonesia
#    ↪️ Trying fallback: Bali 81153, Seririt, Indonesia
#    ✅ Fallback Success: (-8.1925062, 114.9333817)
# [50204/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50205/5000] Geocoding: Jl. Campuhan III, Singakerta, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Campuhan III, Singakerta, Ubud, Indonesia
#    ↪️ Trying fallback: Singakerta, Ubud, Indonesia
#    ✅ Fallback Success: (-8.5275203, 115.2547998)
# [50206/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50207/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50208/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50209/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50210/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50211/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50212/5000] Geocoding: Jl. Rumah Sakit Unud No.77, Jimbaran, Kuta Selatan, Jimbaran, Indonesia
#    ↪️ Trying fallback: Jimbaran, Kuta Selatan, Jimbaran, Indonesia
#    ✅ Fallback Success: (-8.7890328, 115.163417)
# [50213/5000] Geocoding: Jalan Raya Celuk, No.10, Sukawati Gianyar - Bali, Batubulan, Sukawati, Indonesia
#    ↪️ Trying fallback: Sukawati Gianyar - Bali, Batubulan, Sukawati, Indonesia
#    ↪️ Trying fallback: Batubulan, Sukawati, Indonesia
#    ✅ Fallback Success: (-8.6151413, 115.2588933)
# [50214/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50215/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50216/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50217/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50218/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50219/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50220/5000] Geocoding: Jalan Kartika Plaza Jalan Kartika Plaza, Kuta, Indonesia
#    ✅ Found: (-8.7294465, 115.1684268)
# [50221/5000] Geocoding: Jl. Raya Pantai Kuta The Stones - Legian, Legian, Indonesia
#    ↪️ Trying fallback: Jl. Raya Pantai Kuta The Stones - Legian, Legian, Indonesia
#    ↪️ Trying fallback: Legian, Indonesia
#    ✅ Fallback Success: (-8.703338, 115.1688432)
# [50222/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50223/5000] Geocoding: Jl. Nuansa Utama VIII No.6 Kori Nuansa, Taman Geriya, Jimbaran, Indonesia
#    ↪️ Trying fallback: Jl. Nuansa Utama VIII No.6 Kori Nuansa, Taman Geriya, Jimbaran, Indonesia
#    ↪️ Trying fallback: Taman Geriya, Jimbaran, Indonesia
#    ↪️ Trying fallback: Jimbaran, Indonesia
#    ✅ Fallback Success: (-8.7724902, 115.1723944)
# [50224/5000] Geocoding: Jln. Siulan No. 114, Denpasar, Indonesia
#    ↪️ Trying fallback: Jln. Siulan No. 114, Denpasar, Indonesia
#    ↪️ Trying fallback: Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6524973, 115.2191175)
# [50225/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50226/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50227/5000] Geocoding: Jl. Karna No.5, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Karna No.5, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50228/5000] Geocoding: The Kul Kul Farm, Jl. Raya Sibang Kaja Banjar Saren, Abiansemal, Indonesia
#    ↪️ Trying fallback: The Kul Kul Farm, Jl. Raya Sibang Kaja Banjar Saren, Abiansemal, Indonesia
#    ↪️ Trying fallback: Jl. Raya Sibang Kaja Banjar Saren, Abiansemal, Indonesia
#    ↪️ Trying fallback: Abiansemal, Indonesia
#    ✅ Fallback Success: (-8.5249417, 115.2119782)
# [50229/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50230/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50231/5000] Geocoding: Jl. Uluwatu 1 no. 88, Jimbaran, Indonesia
#    ↪️ Trying fallback: Jl. Uluwatu 1 no. 88, Jimbaran, Indonesia
#    ↪️ Trying fallback: Jimbaran, Indonesia
#    ✅ Fallback Success: (-8.7724902, 115.1723944)
# [50232/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50233/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50234/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50235/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50236/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50237/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50238/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50239/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50240/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50241/5000] Geocoding: Jl. Sugriwa no. 8, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Sugriwa no. 8, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50242/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50243/5000] Geocoding: Jl. Nyuh Bulan no. 5 Banjar Nyuh Kuning, Ubud, Indonesia
#    ↪️ Trying fallback: Jl. Nyuh Bulan no. 5 Banjar Nyuh Kuning, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50244/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50245/5000] Geocoding: Jalan Bisma No 888 X, Ubud, Indonesia
#    ↪️ Trying fallback: Jalan Bisma No 888 X, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50246/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50247/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50248/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50249/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50250/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50251/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50252/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50253/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50254/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50255/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50256/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50257/5000] Geocoding: Gang Pudak No. 2 Banjar Dinas Dangin Margi, Pemaron, Lovina Beach, Indonesia
#    ↪️ Trying fallback: Gang Pudak No. 2 Banjar Dinas Dangin Margi, Pemaron, Lovina Beach, Indonesia
#    ↪️ Trying fallback: Pemaron, Lovina Beach, Indonesia
#    ↪️ Trying fallback: Lovina Beach, Indonesia
#    ✅ Fallback Success: (-8.1593111, 115.0256024)
# [50258/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50259/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50260/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50261/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50262/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50263/5000] Geocoding: Jalan Raya Ubud Next to Betelnut, opposite to Puri Lukisan, Ubud, Indonesia
#    ↪️ Trying fallback: Jalan Raya Ubud Next to Betelnut, opposite to Puri Lukisan, Ubud, Indonesia
#    ↪️ Trying fallback: opposite to Puri Lukisan, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50264/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50265/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50266/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50267/5000] Geocoding: Jl. Camplung Tanduk Komp. Pertokoan Abimanyu No. 103 A, Seminyak, Indonesia
#    ↪️ Trying fallback: Jl. Camplung Tanduk Komp. Pertokoan Abimanyu No. 103 A, Seminyak, Indonesia
#    ↪️ Trying fallback: Seminyak, Indonesia
#    ✅ Fallback Success: (-8.6908357, 115.1641975)
# [50268/5000] Geocoding: Jl. Geriya Mas 55, Tumbakbayuh, Mengwi, Indonesia
#    ↪️ Trying fallback: Jl. Geriya Mas 55, Tumbakbayuh, Mengwi, Indonesia
#    ↪️ Trying fallback: Tumbakbayuh, Mengwi, Indonesia
#    ↪️ Trying fallback: Mengwi, Indonesia
#    ✅ Fallback Success: (-8.5448561, 115.1691369)
# [50269/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50270/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50271/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50272/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50273/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50274/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50275/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50276/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50277/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50278/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50279/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50280/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50281/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50282/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50283/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50284/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50285/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50286/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50287/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50288/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50289/5000] Geocoding: Jalan Raya Sanggian Jl. Raya Sanggingan No.88, Kedewatan, Kecamatan Ubud, Kabupaten Gianyar, Bali 80571, Ubud, Indonesia
#    ↪️ Trying fallback: Kabupaten Gianyar, Bali 80571, Ubud, Indonesia
#    ✅ Fallback Success: (-8.5088387, 115.2703173)
# [50290/5000] Geocoding: Jalan Jungutbatu, Indonesia
#    ↪️ Trying fallback: Jalan Jungutbatu, Indonesia
#    ↪️ Trying fallback: Indonesia
#    ✅ Fallback Success: (-2.4833826, 117.8902853)
# [50291/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50292/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50293/5000] Geocoding: Seminyak, Denpasar, Indonesia
#    ✅ Found: (-8.692501, 115.1807869)
# [50294/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50295/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50296/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50297/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50298/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50299/5000] Geocoding: Rapuan II Jl. Banjar Juga, Mas Ubud, Mas, Ubud, Indonesia
#    ↪️ Trying fallback: Mas Ubud, Mas, Ubud, Indonesia
#    ✅ Fallback Success: (-8.5446439, 115.2721291)
# [50300/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50301/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50302/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50303/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50304/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50305/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50306/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50307/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50308/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50309/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50310/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50311/5000] Geocoding: Jl. Raya Bayad H8p2+79 Kedisan, Gianyar, Bali, Indonesie, Ubud, Indonesia
#    ↪️ Trying fallback: Bali, Indonesie, Ubud, Indonesia
#    ↪️ Trying fallback: Indonesie, Ubud, Indonesia
#    ✅ Fallback Success: (-8.5070384, 115.2630446)
# [50312/5000] Geocoding: Lembongan Island, Jungutbatu, Indonesia
#    ✅ Found: (-8.6789419, 115.4573313)
# [50313/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50314/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50315/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50316/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50317/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50318/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50319/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50320/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50321/5000] Geocoding: Jl. Pantai Berawa 105.5 Level 2 opposite Konkrete Skate Park, Canggu, Indonesia
#    ↪️ Trying fallback: Jl. Pantai Berawa 105.5 Level 2 opposite Konkrete Skate Park, Canggu, Indonesia
#    ↪️ Trying fallback: Canggu, Indonesia
#    ✅ Fallback Success: (-8.6506193, 115.1365007)
# [50322/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50323/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50324/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50325/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50326/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50327/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50328/5000] Geocoding: Jl. Lebak Sari no. 7 Petitenget, Denpasar, Indonesia
#    ↪️ Trying fallback: Jl. Lebak Sari no. 7 Petitenget, Denpasar, Indonesia
#    ↪️ Trying fallback: Denpasar, Indonesia
#    ✅ Fallback Success: (-8.6524973, 115.2191175)
# [50329/5000] Geocoding: Main Gate Nusa Dua, Nusa Dua, Benoa, Indonesia
#    ↪️ Trying fallback: Main Gate Nusa Dua, Nusa Dua, Benoa, Indonesia
#    ↪️ Trying fallback: Nusa Dua, Benoa, Indonesia
#    ✅ Fallback Success: (-8.8016777, 115.2239305)
# [50330/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50331/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50332/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50333/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50334/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50335/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50336/5000] Geocoding: Jl raya dukuh ogang sangkan gunung, sidemen-bali Depan SD negeri Nomor 4 sangkan gunung, Sidemen, Karangasem, Indonesia
#    ↪️ Trying fallback: sidemen-bali Depan SD negeri Nomor 4 sangkan gunung, Sidemen, Karangasem, Indonesia
#    ↪️ Trying fallback: Sidemen, Karangasem, Indonesia
#    ✅ Fallback Success: (-8.4646476, 115.4482101)
# [50337/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50338/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50339/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50340/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50341/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50342/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50343/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50344/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50345/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50346/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50347/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50348/5000] Geocoding: Ubud Main Road 33X, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud Main Road 33X, Ubud, Indonesia
#    ↪️ Trying fallback: Ubud, Indonesia
#    ✅ Fallback Success: (-8.5068977, 115.2622931)
# [50349/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50350/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50351/5000] Geocoding: Jl. Sahadewa Legian Kelod, Kuta, Indonesia
#    ↪️ Trying fallback: Jl. Sahadewa Legian Kelod, Kuta, Indonesia
#    ↪️ Trying fallback: Kuta, Indonesia
#    ✅ Fallback Success: (-8.7278354, 115.1730049)
# [50352/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50353/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50354/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50355/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50356/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50357/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50358/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50359/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50360/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50361/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50362/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50363/5000] Geocoding: Jl. Batu Bolong 5, Canggu, Indonesia
#    ↪️ Trying fallback: Jl. Batu Bolong 5, Canggu, Indonesia
#    ↪️ Trying fallback: Canggu, Indonesia
#    ✅ Fallback Success: (-8.6506193, 115.1365007)
# [50364/5000] Geocoding: Jl. Raya Uluwatu Above Pepito Express, Ungasan, Indonesia
#    ↪️ Trying fallback: Jl. Raya Uluwatu Above Pepito Express, Ungasan, Indonesia
#    ↪️ Trying fallback: Ungasan, Indonesia
#    ✅ Fallback Success: (-8.8274318, 115.1568933)
# [50365/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50366/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50367/5000] Geocoding: Jl. Raya Candidasa, Candidasa, Karangasem, Indonesia
#    ✅ Found: (-8.5105522, 115.5726577)
# [50368/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50369/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50370/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50371/5000] Geocoding: Jl. Bingin Sari Pondok Belong, Jimbaran, Indonesia
#    ↪️ Trying fallback: Jl. Bingin Sari Pondok Belong, Jimbaran, Indonesia
#    ↪️ Trying fallback: Jimbaran, Indonesia
#    ✅ Fallback Success: (-8.7724902, 115.1723944)
# [50372/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50373/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50374/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50375/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50376/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50377/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50378/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50379/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50380/5000] Geocoding: Jl Raya, Ubud, Indonesia
#    ✅ Found: (-8.518951, 115.2399529)
# [50381/5000] Geocoding: Jl. Raya Besakih no. 351, Klungkung, Indonesia
#    ↪️ Trying fallback: Jl. Raya Besakih no. 351, Klungkung, Indonesia
#    ↪️ Trying fallback: Klungkung, Indonesia
#    ✅ Fallback Success: (-8.7446026, 115.5575442)
# [50382/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50383/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50384/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50385/5000] Geocoding: Jl. Pantai Berawa No.8, Canggu, Tibubeneng JI. Pantai Berawa No.8, Tibubeneng, Kec. Kuta Utara, Kabupaten Badung, Bali, Canggu, Indonesia
#    ↪️ Trying fallback: Kabupaten Badung, Bali, Canggu, Indonesia
#    ↪️ Trying fallback: Bali, Canggu, Indonesia
#    ✅ Fallback Success: (-8.6432734, 115.1429325)
# [50386/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50387/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50388/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50389/5000] Geocoding: Jl. Jatayu, Ubud, Indonesia
#    ✅ Found: (-8.5166226, 115.2663442)
# [50390/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50391/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50392/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50393/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50394/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50395/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50396/5000] Geocoding: Jl. Pantai Legian, Legian, Indonesia
#    ✅ Found: (-8.7111076, 115.1672228)
# [50397/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50398/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50399/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50400/5000] Geocoding: Jalan Raya Sanggingan Como Uma Ubud, Kedewatan, Ubud, Indonesia
#    ↪️ Trying fallback: Jalan Raya Sanggingan Como Uma Ubud, Kedewatan, Ubud, Indonesia
#    ↪️ Trying fallback: Kedewatan, Ubud, Indonesia
#    ✅ Fallback Success: (-8.5211781, 115.2392701)
# [50401/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50402/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50403/5000] Geocoding: Bali, Indonesia
#    ✅ Found: (-8.2271303, 115.1919203)
# [50404/5000] Geocoding: Jl. Mertanadi No. 15, Seminyak, Indonesia
#    ✅ Found: (-8.6826891, 115.167232)
# [50405/5000] Geocoding: Bali, Indonesia
# ...
#    ↪️ Trying fallback: Cluny Court, Singapore, Singapore
#    ✅ Fallback Success: (1.3226137, 103.8142727)
# [72713/2810] Geocoding: 12 Marina View Asia Square Tower 2, in The Westin Singapore, Singapore, Singapore
#    ↪️ Trying fallback: 12 Marina View Asia Square Tower 2, in The Westin Singapore, Singapore, Singapore
#    ↪️ Trying fallback: in The Westin Singapore, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72714/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72715/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72716/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72717/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72718/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72719/2810] Geocoding: 138 Market Street Levels 39, Singapore, Singapore
#    ↪️ Trying fallback: 138 Market Street Levels 39, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72720/2810] Geocoding: 1 Fullerton Road 02-01 One Fullerton, Singapore, Singapore
#    ↪️ Trying fallback: 1 Fullerton Road 02-01 One Fullerton, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72721/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72722/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72723/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72724/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72725/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72726/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72727/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72728/2810] Geocoding: 45 Craig Road, Singapore, Singapore
#    ✅ Found: (1.2779435, 103.841965)
# [72729/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72730/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72731/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72732/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72733/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72734/2810] Geocoding: 30 Raffles Place Chevron House #02-26, Chevron House, Singapore, Singapore
#    ↪️ Trying fallback: 30 Raffles Place Chevron House #02-26, Chevron House, Singapore, Singapore
#    ↪️ Trying fallback: Chevron House, Singapore, Singapore
#    ✅ Fallback Success: (1.2841645, 103.8519646)
# [72735/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72736/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72737/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72738/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72739/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72740/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72741/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72742/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72743/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72744/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72745/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72746/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72747/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72748/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72749/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72750/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72751/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72752/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72753/2810] Geocoding: 470 North Bridge Road Bugis Cube #03-08 Bugis Cube Shopping Mall, Singapore, Singapore
#    ↪️ Trying fallback: 470 North Bridge Road Bugis Cube #03-08 Bugis Cube Shopping Mall, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72754/2810] Geocoding: 140 Hill Street Old Hill Street Police Station # 01 10 12 11, Singapore, Singapore
#    ↪️ Trying fallback: 140 Hill Street Old Hill Street Police Station # 01 10 12 11, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72755/2810] Geocoding: 296 River Valley Rd, Singapore, Singapore
#    ✅ Found: (1.2954336, 103.8417071)
# [72756/2810] Geocoding: 155 Waterloo Street Stamford Arts Centre, Singapore, Singapore
#    ↪️ Trying fallback: 155 Waterloo Street Stamford Arts Centre, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72757/2810] Geocoding: 13A Dempsey Road, Singapore, Singapore
#    ✅ Found: (1.3046005, 103.8106376)
# [72758/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72759/2810] Geocoding: 390 Orchard Road Palais Renaissance Palais Renaissance, Singapore, Singapore
#    ↪️ Trying fallback: 390 Orchard Road Palais Renaissance Palais Renaissance, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72760/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72761/2810] Geocoding: 247 Beach Road Level 2, Singapore, Singapore
#    ↪️ Trying fallback: 247 Beach Road Level 2, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72762/2810] Geocoding: 1 North Bridge Road High Street Centre #01-46, High Street Centre, Singapore, Singapore
#    ↪️ Trying fallback: 1 North Bridge Road High Street Centre #01-46, High Street Centre, Singapore, Singapore
#    ↪️ Trying fallback: High Street Centre, Singapore, Singapore
#    ✅ Fallback Success: (1.2899732, 103.8492506)
# [72763/2810] Geocoding: #03-01, 35 Kreta Ayer Rd, Singapore, Singapore
#    ↪️ Trying fallback: #03-01, 35 Kreta Ayer Rd, Singapore, Singapore
#    ↪️ Trying fallback: 35 Kreta Ayer Rd, Singapore, Singapore
#    ✅ Fallback Success: (1.2807298, 103.8421572)
# [72764/2810] Geocoding: 60 Paya Lebar Road Paya Lebar Square #07-54, Singapore, Singapore
#    ↪️ Trying fallback: 60 Paya Lebar Road Paya Lebar Square #07-54, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72765/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72766/2810] Geocoding: 21 Woodlands Close #07-42 Primz Bizhub, Singapore, Singapore
#    ↪️ Trying fallback: 21 Woodlands Close #07-42 Primz Bizhub, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72767/2810] Geocoding: 1 Yuan Ching Road Superbowl Jurong #02-03 Jurong Superbowl, Singapore, Singapore
#    ↪️ Trying fallback: 1 Yuan Ching Road Superbowl Jurong #02-03 Jurong Superbowl, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72768/2810] Geocoding: 66 Haji Lane, Singapore, Singapore
#    ✅ Found: (1.3013926, 103.8586904)
# [72769/2810] Geocoding: 290 Joo Chiat Road, Singapore, Singapore
#    ✅ Found: (1.3123779, 103.9000793)
# [72770/2810] Geocoding: 63 Hillview Avenue Lam Soon Industrial Building #10-06a, Singapore, Singapore
#    ↪️ Trying fallback: 63 Hillview Avenue Lam Soon Industrial Building #10-06a, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72771/2810] Geocoding: 6 Eu Tong Sen Street #01-41 the Central, Singapore, Singapore
#    ↪️ Trying fallback: 6 Eu Tong Sen Street #01-41 the Central, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72772/2810] Geocoding: 19 Tanglin Road Tanglin Shopping Centre #B1-07 Tanglin Shopping Centre, Singapore, Singapore
#    ↪️ Trying fallback: 19 Tanglin Road Tanglin Shopping Centre #B1-07 Tanglin Shopping Centre, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72773/2810] Geocoding: 1 Kim Seng Promenade Great World City 02-12/13, Singapore, Singapore
#    ↪️ Trying fallback: 1 Kim Seng Promenade Great World City 02-12/13, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72774/2810] Geocoding: 11 Cavenagh Road Holiday Inn Singapore Orchard City Centre Floor 01 Unit 09 08 Holiday Inn Orchard City Centre, Singapore, Singapore
#    ↪️ Trying fallback: 11 Cavenagh Road Holiday Inn Singapore Orchard City Centre Floor 01 Unit 09 08 Holiday Inn Orchard City Centre, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72775/2810] Geocoding: 452 North Bridge Road Chan Brothers Building Chan Brothers Building #06-00, Singapore, Singapore
#    ↪️ Trying fallback: 452 North Bridge Road Chan Brothers Building Chan Brothers Building #06-00, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72776/2810] Geocoding: 1A Cuscaden Road Hotel Jen Tanglin Singapore Level 4, Fitness Centre, Singapore, Singapore
#    ↪️ Trying fallback: 1A Cuscaden Road Hotel Jen Tanglin Singapore Level 4, Fitness Centre, Singapore, Singapore
#    ↪️ Trying fallback: Fitness Centre, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72777/2810] Geocoding: 334 Sembawang Close Block 334, , Singapore, Singapore
#    ↪️ Trying fallback: 334 Sembawang Close Block 334, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72778/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72779/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72780/2810] Geocoding: 1 Maju Avenue Myvillage At Serangoon Garden #01-03, Singapore, Singapore
#    ↪️ Trying fallback: 1 Maju Avenue Myvillage At Serangoon Garden #01-03, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72781/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72782/2810] Geocoding: 491B River Valley Road Valley Point 7 mins walk from Bugis MRT station, Singapore, Singapore
#    ↪️ Trying fallback: 491B River Valley Road Valley Point 7 mins walk from Bugis MRT station, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72783/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72784/2810] Geocoding: 20 Upper Circular Road #01-15 the Riverwalk, Singapore, Singapore
#    ↪️ Trying fallback: 20 Upper Circular Road #01-15 the Riverwalk, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72785/2810] Geocoding: 317 Outram Road Concorde Shopping Centre 02-21 Holiday Inn Atrium, Singapore, Singapore
#    ↪️ Trying fallback: 317 Outram Road Concorde Shopping Centre 02-21 Holiday Inn Atrium, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72786/2810] Geocoding: 56 Circular Road Level 3 Molly Malones, Singapore, Singapore
#    ↪️ Trying fallback: 56 Circular Road Level 3 Molly Malones, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72787/2810] Geocoding: 220 Turf Club Road The Cage Sports Park, Singapore, Singapore
#    ↪️ Trying fallback: 220 Turf Club Road The Cage Sports Park, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72788/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72789/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72790/2810] Geocoding: 70A Bussorah Street, Singapore, Singapore
#    ✅ Found: (1.3007517, 103.8602173)
# [72791/2810] Geocoding: 513 Bishan Street 13 #01-510 opposite CPF Board Building, Singapore, Singapore
#    ↪️ Trying fallback: 513 Bishan Street 13 #01-510 opposite CPF Board Building, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72792/2810] Geocoding: 1 Coleman Street The Adelphi #03-28, Singapore, Singapore
#    ↪️ Trying fallback: 1 Coleman Street The Adelphi #03-28, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72793/2810] Geocoding: 848 Sims Avenue #01-738 Eunos, Singapore, Singapore
#    ✅ Found: (1.3173673, 103.9012619)
# [72794/2810] Geocoding: 84 Joo Chiat Place, Singapore, Singapore
#    ✅ Found: (1.3143119, 103.9065478)
# [72795/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72796/2810] Geocoding: 122 Bedok North Street 2 #01-132, Singapore, Singapore
#    ✅ Found: (1.3291285, 103.938031)
# [72797/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72798/2810] Geocoding: 503 Jurong West Avenue 1 Hong Kah Court #03-845, Singapore, Singapore
#    ↪️ Trying fallback: 503 Jurong West Avenue 1 Hong Kah Court #03-845, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72799/2810] Geocoding: 201 Victoria Street Bugis+ Bugis+, Singapore, Singapore
#    ✅ Found: (1.2996673, 103.8541904)
# [72800/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72801/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72802/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72803/2810] Geocoding: 48 Boon Lay Way The Chevrons Suite #01-10, Singapore, Singapore
#    ↪️ Trying fallback: 48 Boon Lay Way The Chevrons Suite #01-10, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72804/2810] Geocoding: 5 Sengkang Square #02-02 Sengkang Mrt Station Sengkang Mrt Station, Singapore, Singapore
#    ↪️ Trying fallback: 5 Sengkang Square #02-02 Sengkang Mrt Station Sengkang Mrt Station, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72805/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# [72806/2810] Geocoding: 44 Toh Tuck Road Goodluck Garden #01-07, Singapore, Singapore
#    ↪️ Trying fallback: 44 Toh Tuck Road Goodluck Garden #01-07, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72807/2810] Geocoding: 118 Rivervale Drive Rivervale Plaza Rivervale Plaza, Singapore, Singapore
#    ↪️ Trying fallback: 118 Rivervale Drive Rivervale Plaza Rivervale Plaza, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72808/2810] Geocoding: 446 Clementi Avenue 3 #01-197, Singapore, Singapore
#    ✅ Found: (1.3125049, 103.7649184)
# [72809/2810] Geocoding: 61 Ang Mo Kio Avenue 8 #02-06 Jubilee Square, Singapore, Singapore
#    ↪️ Trying fallback: 61 Ang Mo Kio Avenue 8 #02-06 Jubilee Square, Singapore, Singapore
#    ↪️ Trying fallback: Singapore, Singapore
#    ✅ Fallback Success: (1.2899175, 103.8519072)
# [72810/2810] Geocoding: Singapore, Singapore
#    ✅ Found: (1.2899175, 103.8519072)
# 💾 Đã lưu: geo_batches_attractions/geo_results_batch_15.csv

# %%
import glob

all_batches = sorted(glob.glob("geo_batches_attractions/geo_results_batch_*.csv"))
df_full = pd.concat((pd.read_csv(f) for f in all_batches), ignore_index=True)

df_full.to_csv("D:\\20242\\Web_GProject\\data\\attractions.csv", index=False)

# %%
from geopy.distance import geodesic

# Geocode địa điểm người dùng nhập
def get_coordinates_from_address(address):
    geolocator = Nominatim(user_agent="user_location_finder", timeout=10)
    location = geolocator.geocode(address)
    if location:
        return (location.latitude, location.longitude)
    else:
        print(f"❌ Không tìm thấy tọa độ cho địa chỉ: {address}")
        return None

# Tìm khách sạn gần địa điểm đó nhất
def find_nearby_hotels(user_input_address, df, radius_km=10):
    user_coords = get_coordinates_from_address(user_input_address)
    if not user_coords:
        return pd.DataFrame()
    
    # Chỉ lấy những khách sạn đã có tọa độ
    df_valid = df.dropna(subset=['latitude', 'longitude']).copy()

    # Tính khoảng cách từng khách sạn đến vị trí người dùng
    df_valid['distance_km'] = df_valid.apply(
        lambda row: geodesic(user_coords, (row['latitude'], row['longitude'])).km,
        axis=1
    )

    # Lọc theo bán kính và sắp xếp
    nearby = df_valid[df_valid['distance_km'] <= radius_km]
    return nearby.sort_values('distance_km')[['Name', 'Address', 'Price', 'Overall Rating Value', 'distance_km']]

# %%
# Ví dụ địa chỉ người dùng nhập:
user_location = "Chonburi"

# Tìm khách sạn gần trong bán kính 10 km
nearby_hotels = find_nearby_hotels(user_location, df_full, radius_km=10)

# Hiển thị kết quả
nearby_hotels.head(10)
# Out:
#                                        Name  \
# 43822       Hotel Nikko Amata City Chonburi
# 44660                     Baan Lanna Resort
# 44661                    Homer Resort Hotel
# 44662  Tassana Place Boutique Hotel Bansuan
# 44663      Bangsean Royal Beach by Preyaluk
# 44665                              Narasiri
# 44666               Don Khun Wang Mansion 2
# 44667                 Premiercondo Chonburi
# 44668               Nanglen Kan Him Risxrth
# 44670                    TPR51 Room Service
#
#                                                  Address          Price  \
# 43822  700/333 Moo 1 Klongtamru Muang, Chonburi, Thai...           80.0
# 44660                  114/188 Samet, Chonburi, Thailand           26.0
# 44661  58/53 Moo 3 Ban Bueng Sub-district, Chonburi, ...           11.0
# 44662             62/333 Kutichi M.2, Chonburi, Thailand           24.0
# 44663  148 Moo 13, Bangsaen Road Line 1, Saensuk Subd...  Unknown price
# 44665  145/14 Moo.4 Prasoet Rat Phatthana 5 Bannongch...  Unknown price
# 44666      59/99 Moo 2 T.Don Hua Roh, Chonburi, Thailand           14.0
# 44667  Phraya Satcha Rd. 250 Soi Ban Suan-Phraya Satc...           48.0
# 44668   128/29 M.3 Th. Phraya Sac Ca, Chonburi, Thailand           27.0
# 44670  51 Bang Saen Sai 2 Road Soi 12, Chonburi, Thai...           26.0
#
#        Overall Rating Value  distance_km
# 43822                   4.9          0.0
# 44660                  -1.0          0.0
# 44661                  -1.0          0.0
# 44662                  -1.0          0.0
# 44663                  -1.0          0.0
# 44665                  -1.0          0.0
# 44666                  -1.0          0.0
# 44667                  -1.0          0.0
# 44668                  -1.0          0.0
# 44670                  -1.0          0.0
